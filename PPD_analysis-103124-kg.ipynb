# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Load and process data

# %%
df = pd.read_csv("/Users/gallsigler/Library/CloudStorage/Box-Box/ppd/PPD_data.csv").iloc[2:,:]
df = df[df['Status']=="IP Address"] # remove Survey Preview
df = df.replace({'Agree':'Somewhat agree','Disagree':'Somewhat disagree'})
df['Q39-3'] = df['Q39-1'].fillna(df['Q39-2'])
df['Q39-3'] = df['Q39-3'].replace({'1-2 years': '0-2 years'})
df['Q12-3'] = df['Q12-1'].fillna(df['Q12-2'])
df['Q36'] = df['Q36'].replace({'Non-binary':'Other'})
df['Q37'] = df['Q37'].replace({'Native American or Alaskan Native':'A race/ethnicity not listed here'})

df['Date'] = pd.to_datetime(df['RecordedDate']).dt.date
df = df[df['Date'] >= pd.to_datetime('2024-10-23').date()]

df['Progress'] = df['Progress'].astype(int)
df
# Out:
# /var/folders/1w/pt0qck1176q3lbp58s3lbgm40000gn/T/ipykernel_86533/3703239348.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({'Agree':'Somewhat agree','Disagree':'Somewhat disagree'})
#                 StartDate              EndDate      Status       IPAddress  \
# 23    2024-10-23 08:01:06  2024-10-23 08:09:32  IP Address  170.115.248.25
# 24    2024-10-23 08:01:22  2024-10-23 08:09:41  IP Address  170.115.248.25
# 25    2024-10-23 08:01:11  2024-10-23 08:10:10  IP Address   104.28.76.117
# 26    2024-10-23 08:05:16  2024-10-23 08:11:25  IP Address   170.115.248.7
# 27    2024-10-23 08:01:43  2024-10-23 08:12:23  IP Address    73.81.200.11
# ...                   ...                  ...         ...             ...
# 1308  2024-11-18 13:33:29  2024-11-18 13:37:05  IP Address  170.115.248.24
# 1309  2024-11-19 08:04:31  2024-11-19 08:05:23  IP Address  170.115.248.14
# 1310  2024-11-19 09:18:10  2024-11-19 09:22:21  IP Address  104.254.17.141
# 1311  2024-11-19 22:50:08  2024-11-19 22:50:13  IP Address   136.226.19.59
# 1312  2024-11-20 10:05:10  2024-11-20 10:05:23  IP Address  170.115.248.14
#
#       Progress Duration (in seconds) Finished         RecordedDate  \
# 23         100                   505     True  2024-10-23 08:09:32
# 24         100                   499     True  2024-10-23 08:09:42
# 25         100                   538     True  2024-10-23 08:10:10
# 26         100                   368     True  2024-10-23 08:11:25
# 27         100                   639     True  2024-10-23 08:12:23
# ...        ...                   ...      ...                  ...
# 1308        37                   215    False  2024-11-20 16:32:51
# 1309        12                    51    False  2024-11-20 16:32:51
# 1310        33                   251    False  2024-11-20 16:32:51
# 1311         2                     5    False  2024-11-20 16:32:51
# 1312         2                    13    False  2024-11-20 16:32:51
#
#              ResponseId  RecipientLastName  RecipientFirstName  \
# 23    R_1S6S2YOLmv7QIc9                NaN                 NaN
# 24    R_3nSYgHp2Rm797hf                NaN                 NaN
# 25    R_6N9Q7PpNf0cQm2o                NaN                 NaN
# 26    R_6VyhD3VcG9CxJCE                NaN                 NaN
# 27    R_5iNYMYTrpdrYl2p                NaN                 NaN
# ...                 ...                ...                 ...
# 1308  R_5CijkmjipIFKfyV                NaN                 NaN
# 1309  R_5f3r2YTuSOQ8oaI                NaN                 NaN
# 1310  R_5CdrMs6s2Ld9ozB                NaN                 NaN
# 1311  R_5MSD4JDUEwz8GB4                NaN                 NaN
# 1312  R_59sSUEYZrNc2m1H                NaN                 NaN
#
#       RecipientEmail  ExternalReference LocationLatitude LocationLongitude  \
# 23               NaN                NaN          40.0149          -75.1439
# 24               NaN                NaN          40.0149          -75.1439
# 25               NaN                NaN          39.9843          -75.2266
# 26               NaN                NaN          40.0149          -75.1439
# 27               NaN                NaN          40.0172          -75.0883
# ...              ...                ...              ...               ...
# 1308             NaN                NaN              NaN               NaN
# 1309             NaN                NaN              NaN               NaN
# 1310             NaN                NaN              NaN               NaN
# 1311             NaN                NaN              NaN               NaN
# 1312             NaN                NaN              NaN               NaN
#
#      DistributionChannel UserLanguage  QID1  QID79                 Q1  \
# 23             anonymous           EN   NaN    NaN  Somewhat disagree
# 24             anonymous           EN   NaN    NaN  Strongly disagree
# 25             anonymous           EN   NaN    NaN     Somewhat agree
# 26             anonymous           EN   NaN    NaN     Strongly agree
# 27             anonymous           EN   NaN    NaN  Strongly disagree
# ...                  ...          ...   ...    ...                ...
# 1308           anonymous           EN   NaN    NaN  Strongly disagree
# 1309           anonymous           EN   NaN    NaN  Strongly disagree
# 1310           anonymous           EN   NaN    NaN  Strongly disagree
# 1311           anonymous           EN   NaN    NaN                NaN
# 1312           anonymous           EN   NaN    NaN                NaN
#
#                        Q2                 Q3                 Q4  \
# 23    Don't know/not sure     Somewhat agree  Somewhat disagree
# 24      Strongly disagree  Somewhat disagree  Strongly disagree
# 25      Somewhat disagree     Somewhat agree  Somewhat disagree
# 26         Somewhat agree     Strongly agree     Somewhat agree
# 27      Strongly disagree  Strongly disagree  Strongly disagree
# ...                   ...                ...                ...
# 1308    Strongly disagree  Somewhat disagree  Strongly disagree
# 1309       Somewhat agree  Somewhat disagree  Somewhat disagree
# 1310       Strongly agree  Strongly disagree  Strongly disagree
# 1311                  NaN                NaN                NaN
# 1312                  NaN                NaN                NaN
#
#                  Q5_1             Q5_2             Q5_3             Q5_4  \
# 23      Somewhat well    Somewhat well     Not too well    Somewhat well
# 24    Not well at all  Not well at all  Not well at all  Not well at all
# 25      Somewhat well    Somewhat well    Somewhat well    Somewhat well
# 26          Very well        Very well    Somewhat well        Very well
# 27    Not well at all  Not well at all  Not well at all  Not well at all
# ...               ...              ...              ...              ...
# 1308  Not well at all  Not well at all  Not well at all     Not too well
# 1309              NaN              NaN              NaN              NaN
# 1310     Not too well     Not too well  Not well at all  Not well at all
# 1311              NaN              NaN              NaN              NaN
# 1312              NaN              NaN              NaN              NaN
#
#                      Q6          Q7  QID43              Q8  \
# 23            Satisfied    Not sure    NaN  Somewhat agree
# 24    Very dissatisfied    Too much    NaN  Strongly agree
# 25            Satisfied    Not sure    NaN  Somewhat agree
# 26            Satisfied    Too much    NaN  Somewhat agree
# 27    Very dissatisfied    Too much    NaN  Strongly agree
# ...                 ...         ...    ...             ...
# 1308  Very dissatisfied  Too little    NaN  Somewhat agree
# 1309                NaN         NaN    NaN             NaN
# 1310       Dissatisfied    Too much    NaN  Strongly agree
# 1311                NaN         NaN    NaN             NaN
# 1312                NaN         NaN    NaN             NaN
#
#                        Q9                Q10              Q11_1  \
# 23         Somewhat agree     Somewhat agree            Neutral
# 24      Strongly disagree  Strongly disagree     Strongly agree
# 25    Don't know/Not sure  Somewhat disagree            Neutral
# 26         Somewhat agree     Somewhat agree     Somewhat agree
# 27         Strongly agree     Strongly agree     Strongly agree
# ...                   ...                ...                ...
# 1308       Somewhat agree  Somewhat disagree  Somewhat disagree
# 1309                  NaN                NaN                NaN
# 1310       Strongly agree  Strongly disagree     Strongly agree
# 1311                  NaN                NaN                NaN
# 1312                  NaN                NaN                NaN
#
#                   Q11_2              Q11_3              Q12_1  \
# 23    Somewhat disagree            Neutral  Somewhat disagree
# 24    Strongly disagree  Strongly disagree  Somewhat disagree
# 25       Somewhat agree     Somewhat agree     Somewhat agree
# 26       Somewhat agree     Somewhat agree  Strongly disagree
# 27       Strongly agree     Strongly agree     Strongly agree
# ...                 ...                ...                ...
# 1308  Strongly disagree  Strongly disagree     Strongly agree
# 1309                NaN                NaN                NaN
# 1310  Strongly disagree     Strongly agree     Strongly agree
# 1311                NaN                NaN                NaN
# 1312                NaN                NaN                NaN
#
#                   Q12_2                                              Q12-1  \
# 23       Somewhat agree                                                NaN
# 24    Strongly disagree                                                NaN
# 25       Somewhat agree                                                NaN
# 26    Somewhat disagree                                                NaN
# 27       Strongly agree                                        Race,Gender
# ...                 ...                                                ...
# 1308     Strongly agree                                      Race,Religion
# 1309                NaN                                                NaN
# 1310     Somewhat agree  Race,Sex,Gender,Family care status/your respon...
# 1311                NaN                                                NaN
# 1312                NaN                                                NaN
#
#      Q12-1_11_TEXT              Q12-2 Q12-2_11_TEXT  QID47              Q13_1  \
# 23             NaN                NaN           NaN    NaN            Neutral
# 24             NaN                NaN           NaN    NaN  Strongly disagree
# 25             NaN  Race,Age,Not sure           NaN    NaN     Somewhat agree
# 26             NaN                NaN           NaN    NaN     Somewhat agree
# 27             NaN                NaN           NaN    NaN     Strongly agree
# ...            ...                ...           ...    ...                ...
# 1308           NaN                NaN           NaN    NaN  Somewhat disagree
# 1309           NaN                NaN           NaN    NaN                NaN
# 1310           NaN                NaN           NaN    NaN                NaN
# 1311           NaN                NaN           NaN    NaN                NaN
# 1312           NaN                NaN           NaN    NaN                NaN
#
#                   Q13_2              Q13_3              Q13_4  \
# 23              Neutral            Neutral  Somewhat disagree
# 24    Strongly disagree  Strongly disagree  Strongly disagree
# 25       Somewhat agree     Somewhat agree            Neutral
# 26       Somewhat agree     Somewhat agree     Somewhat agree
# 27       Strongly agree     Strongly agree     Strongly agree
# ...                 ...                ...                ...
# 1308            Neutral  Strongly disagree  Strongly disagree
# 1309                NaN                NaN                NaN
# 1310                NaN                NaN                NaN
# 1311                NaN                NaN                NaN
# 1312                NaN                NaN                NaN
#
#                   Q13_5              Q13_6  \
# 23              Neutral            Neutral
# 24       Strongly agree  Strongly disagree
# 25              Neutral            Neutral
# 26    Somewhat disagree            Neutral
# 27    Strongly disagree  Strongly disagree
# ...                 ...                ...
# 1308     Strongly agree     Strongly agree
# 1309                NaN                NaN
# 1310                NaN                NaN
# 1311                NaN                NaN
# 1312                NaN                NaN
#
#                                                     Q14          Q15  \
# 23                                                  NaN        Never
# 24    Nothing they aren't cops and never will be the...  Hardly ever
# 25                                                  NaN  Hardly ever
# 26                                                  NaN    Sometimes
# 27                                                  NaN  Hardly ever
# ...                                                 ...          ...
# 1308                                                NaN          NaN
# 1309                                                NaN          NaN
# 1310                                                NaN          NaN
# 1311                                                NaN          NaN
# 1312                                                NaN          NaN
#
#                     Q16              Q17_1              Q17_2  \
# 23    Strongly disagree     Somewhat agree     Somewhat agree
# 24    Strongly disagree  Somewhat disagree  Somewhat disagree
# 25       Somewhat agree     Somewhat agree     Somewhat agree
# 26       Somewhat agree     Strongly agree     Strongly agree
# 27    Strongly disagree  Strongly disagree  Strongly disagree
# ...                 ...                ...                ...
# 1308                NaN                NaN                NaN
# 1309                NaN                NaN                NaN
# 1310                NaN                NaN                NaN
# 1311                NaN                NaN                NaN
# 1312                NaN                NaN                NaN
#
#                   Q18              Q19                Q20          Q21  \
# 23    Not well at all     Not too well     Somewhat agree    Sometimes
# 24    Not well at all  Not well at all     Strongly agree  Hardly ever
# 25      Somewhat well     Not too well  Somewhat disagree    Sometimes
# 26      Somewhat well    Somewhat well     Strongly agree       Always
# 27    Not well at all  Not well at all     Strongly agree       Always
# ...               ...              ...                ...          ...
# 1308              NaN              NaN                NaN          NaN
# 1309              NaN              NaN                NaN          NaN
# 1310              NaN              NaN                NaN          NaN
# 1311              NaN              NaN                NaN          NaN
# 1312              NaN              NaN                NaN          NaN
#
#                                                     Q22              Q23_1  \
# 23                                                  NaN  Strongly disagree
# 24    you have to be in the in crowd its all in who ...  Strongly disagree
# 25    Not enough opportunities or denial of opportun...  Somewhat disagree
# 26                                                  NaN     Somewhat agree
# 27                                                  NaN  Strongly disagree
# ...                                                 ...                ...
# 1308                                                NaN                NaN
# 1309                                                NaN                NaN
# 1310                                                NaN                NaN
# 1311                                                NaN                NaN
# 1312                                                NaN                NaN
#
#                   Q23_2              Q23_3                Q24  QID48  \
# 23    Strongly disagree  Somewhat disagree     Somewhat agree    NaN
# 24    Strongly disagree  Strongly disagree  Strongly disagree    NaN
# 25    Somewhat disagree  Somewhat disagree     Somewhat agree    NaN
# 26    Somewhat disagree  Somewhat disagree     Strongly agree    NaN
# 27    Strongly disagree  Strongly disagree     Strongly agree    NaN
# ...                 ...                ...                ...    ...
# 1308                NaN                NaN                NaN    NaN
# 1309                NaN                NaN                NaN    NaN
# 1310                NaN                NaN                NaN    NaN
# 1311                NaN                NaN                NaN    NaN
# 1312                NaN                NaN                NaN    NaN
#
#                  Q25                Q26                Q27  \
# 23    Somewhat agree  Strongly disagree  Strongly disagree
# 24    Strongly agree  Strongly disagree  Strongly disagree
# 25    Somewhat agree  Somewhat disagree  Strongly disagree
# 26    Somewhat agree     Strongly agree         Don't know
# 27    Strongly agree  Strongly disagree  Strongly disagree
# ...              ...                ...                ...
# 1308             NaN                NaN                NaN
# 1309             NaN                NaN                NaN
# 1310             NaN                NaN                NaN
# 1311             NaN                NaN                NaN
# 1312             NaN                NaN                NaN
#
#                                                     Q28                Q29  \
# 23                                                  NaN  Strongly disagree
# 24    its who you know doesn't matter about experience   Strongly disagree
# 25    There is too much favoritism and bias in selec...  Strongly disagree
# 26                                                  NaN         Don't know
# 27    The "rule of five" is discriminatory and is in...  Strongly disagree
# ...                                                 ...                ...
# 1308                                                NaN                NaN
# 1309                                                NaN                NaN
# 1310                                                NaN                NaN
# 1311                                                NaN                NaN
# 1312                                                NaN                NaN
#
#                                                     Q30                Q31  \
# 23                                                  NaN  Strongly disagree
# 24    same answer as the last three times you asked it   Strongly disagree
# 25    Not enough communication, a lot of hidden tran...  Somewhat disagree
# 26                                                  NaN     Somewhat agree
# 27    If you know certain high ranking officials, yo...  Strongly disagree
# ...                                                 ...                ...
# 1308                                                NaN                NaN
# 1309                                                NaN                NaN
# 1310                                                NaN                NaN
# 1311                                                NaN                NaN
# 1312                                                NaN                NaN
#
#               Q32  QID58                                            Q33  \
# 23      Sometimes    NaN  Transfers,Training and Development,Promotions
# 24    Hardly ever    NaN                                            NaN
# 25      Sometimes    NaN                 Recruiting,Retention,Transfers
# 26        Usually    NaN                                            NaN
# 27    Hardly ever    NaN                     Retention,Promotions,Other
# ...           ...    ...                                            ...
# 1308          NaN    NaN                                            NaN
# 1309          NaN    NaN                                            NaN
# 1310          NaN    NaN                                            NaN
# 1311          NaN    NaN                                            NaN
# 1312          NaN    NaN                                            NaN
#
#                   Q33_13_TEXT  \
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27    Ending the rule of five
# ...                       ...
# 1308                      NaN
# 1309                      NaN
# 1310                      NaN
# 1311                      NaN
# 1312                      NaN
#
#                                                     Q34  Q35     Q36  \
# 23                                                  NaN   50  Female
# 24                                                  NaN  NaN     NaN
# 25                                                  NaN   32    Male
# 26                                                  NaN   48    Male
# 27    The "rule of five" needs to be ended immediate...   47    Male
# ...                                                 ...  ...     ...
# 1308                                                NaN  NaN     NaN
# 1309                                                NaN  NaN     NaN
# 1310                                                NaN  NaN     NaN
# 1311                                                NaN  NaN     NaN
# 1312                                                NaN  NaN     NaN
#
#      Q36_3_TEXT                        Q37  Q38                     Q39  \
# 23          NaN         White or Caucasian   No                   Sworn
# 24          NaN                        NaN  NaN                     NaN
# 25          NaN  Asian or Pacific Islander  Yes                   Sworn
# 26          NaN         White or Caucasian   No  Non-sworn professional
# 27          NaN         White or Caucasian  Yes                   Sworn
# ...         ...                        ...  ...                     ...
# 1308        NaN                        NaN  NaN                     NaN
# 1309        NaN                        NaN  NaN                     NaN
# 1310        NaN                        NaN  NaN                     NaN
# 1311        NaN                        NaN  NaN                     NaN
# 1312        NaN                        NaN  NaN                     NaN
#
#                    Q39-1        Q39-2               Q39-3  \
# 23    More than 25 years          NaN  More than 25 years
# 24                   NaN          NaN                 NaN
# 25            6-10 years          NaN          6-10 years
# 26                   NaN  16-25 years         16-25 years
# 27    More than 25 years          NaN  More than 25 years
# ...                  ...          ...                 ...
# 1308                 NaN          NaN                 NaN
# 1309                 NaN          NaN                 NaN
# 1310                 NaN          NaN                 NaN
# 1311                 NaN          NaN                 NaN
# 1312                 NaN          NaN                 NaN
#
#                                                   Q12-3        Date
# 23                                                  NaN  2024-10-23
# 24                                                  NaN  2024-10-23
# 25                                    Race,Age,Not sure  2024-10-23
# 26                                                  NaN  2024-10-23
# 27                                          Race,Gender  2024-10-23
# ...                                                 ...         ...
# 1308                                      Race,Religion  2024-11-20
# 1309                                                NaN  2024-11-20
# 1310  Race,Sex,Gender,Family care status/your respon...  2024-11-20
# 1311                                                NaN  2024-11-20
# 1312                                                NaN  2024-11-20
#
# [1290 rows x 87 columns]

# %% [markdown]
# ## Survey distribution

# %%
# Count the number of surveys by date and Finished status
date_finished_distribution = df.groupby(['Date', 'Finished']).size().unstack(fill_value=0)

# Plot the stacked bar chart
date_finished_distribution.plot(
    kind='bar', 
    stacked=True, 
    figsize=(10, 6), 
    color=['#1f77b4', '#ff7f0e'], 
    alpha=0.8
)
plt.title("Survey Distribution by Date (Finished vs. Not Finished)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Surveys", fontsize=12)

# Format x-ticks to show only month and day
plt.xticks(ticks=range(len(date_finished_distribution.index)), 
           labels=[date.strftime('%m-%d') for date in date_finished_distribution.index], 
           rotation=0, fontsize=8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.legend(title="Finished", labels=["Not Finished", "Finished"], fontsize=10)
plt.tight_layout()
# plt.show()

plt.savefig("plots/survey_distribution.png", dpi=300)
plt.show()

# markdown_content += f"![Survey Distribution by Data](/plots/survey_distribution.png)\n\n"

# %%
# # Bin the 'Progress' column
# bins = [0, 25, 50, 90, 95, 100]
# labels = ['0-25', '26-50', '51-90', '91-99', '100']
# df['Progress_Bin'] = pd.cut(df['Progress'], bins=bins, labels=labels, right=True)

# df[['Progress','Progress_Bin']]
# df['Progress_Bin'] = df['Progress_Bin'].astype(str)
# df['Progress_Bin'].value_counts()

# %%
df['Progress'].plot(kind='hist', bins=10, figsize=(8, 6), alpha=0.75)

# Customize the plot
plt.title("Distribution of Progress", fontsize=14)
plt.xlabel("Progress", fontsize=12)
plt.ylabel("Number of Surveys", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.savefig("plots/progress_distribution.png", dpi=300)
plt.show()

# %% [markdown]
# ## IP Address

# %%
import time
import requests

def get_location_from_ip(ip):
    time.sleep(5)
    params = ['query', 'status', 'country', 'countryCode', 'city', 'timezone', 'mobile']
    try:
        # Make the request to the API
        resp = requests.get(f'http://ip-api.com/json/{ip}', params={'fields': ','.join(params)})
        
        # Check if the response was successful
        if resp.status_code == 200:
            # Attempt to parse the response as JSON
            info = resp.json()
            
            # Check if the API status is 'success'
            if info.get('status') == 'success':
                return info.get('city', 'N/A'), info.get('country', 'N/A')
            else:
                print("API response status not successful:", info.get('status'))
                return None, None
        else:
            print(f"Request failed with status code {resp.status_code}")
            return None, None
    except requests.exceptions.RequestException as e:
        print("Request error:", e)
        return None, None
    except ValueError as e:
        print("JSON parsing error:", e)
        return None, None

# get_location_from_ip('170.115.248.25')

# %%
# ip_df = pd.DataFrame(df['IPAddress'].unique(), columns=['IPAddress'])
# ip_df[['City', 'Country']] = ip_df['IPAddress'].apply(lambda ip: pd.Series(get_location_from_ip(ip)))
# ip_df

# %%
ip_df = pd.read_csv('updated_ip.csv').iloc[:,1:]

new_ips = df[~df['IPAddress'].isin(ip_df['IPAddress'])]['IPAddress'].unique()
new_ip_df = pd.DataFrame(new_ips, columns=['IPAddress'])
new_ip_df[['City', 'Country']] = new_ip_df['IPAddress'].apply(lambda ip: pd.Series(get_location_from_ip(ip)))

updated_ip = pd.concat([ip_df, new_ip_df])

updated_ip.to_csv('updated_ip.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1w/pt0qck1176q3lbp58s3lbgm40000gn/T/ipykernel_86533/1649777389.py in ?()
#       1 ip_df = pd.read_csv('updated_ip.csv').iloc[:,1:]
#       2
#       3 new_ips = df[~df['IPAddress'].isin(ip_df['IPAddress'])]['IPAddress'].unique()
#       4 new_ip_df = pd.DataFrame(new_ips, columns=['IPAddress'])
# ----> 5 new_ip_df[['City', 'Country']] = new_ip_df['IPAddress'].apply(lambda ip: pd.Series(get_location_from_ip(ip)))
#       6
#       7 updated_ip = pd.concat([ip_df, new_ip_df])
#       8
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4295
#    4296         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
#    4301             self._set_item_frame_value(key, value)
#    4302         elif (
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4354                 value = DataFrame(value).values
#    4355                 return self._setitem_array(key, value)
#    4356
#    4357             else:
# -> 4358                 self._iset_not_inplace(key, value)
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4373                 return obj[i]
#    4374
#    4375         if self.columns.is_unique:
#    4376             if np.shape(value)[-1] != len(key):
# -> 4377                 raise ValueError("Columns must be same length as key")
#    4378
#    4379             for i, col in enumerate(key):
#    4380                 self[col] = igetitem(value, i)
#
# ValueError: Columns must be same length as key

# %%
updated_ip.to_csv('updated_ip.csv')

# %% [markdown]
# ## Markdown section 1

# %%
updated_ip = pd.read_csv('updated_ip.csv')
df = df.merge(updated_ip, on='IPAddress', how='left')
df
# Out:
#                 StartDate              EndDate      Status       IPAddress  \
# 0     2024-10-23 08:01:06  2024-10-23 08:09:32  IP Address  170.115.248.25
# 1     2024-10-23 08:01:22  2024-10-23 08:09:41  IP Address  170.115.248.25
# 2     2024-10-23 08:01:11  2024-10-23 08:10:10  IP Address   104.28.76.117
# 3     2024-10-23 08:05:16  2024-10-23 08:11:25  IP Address   170.115.248.7
# 4     2024-10-23 08:01:43  2024-10-23 08:12:23  IP Address    73.81.200.11
# ...                   ...                  ...         ...             ...
# 1285  2024-11-18 13:33:29  2024-11-18 13:37:05  IP Address  170.115.248.24
# 1286  2024-11-19 08:04:31  2024-11-19 08:05:23  IP Address  170.115.248.14
# 1287  2024-11-19 09:18:10  2024-11-19 09:22:21  IP Address  104.254.17.141
# 1288  2024-11-19 22:50:08  2024-11-19 22:50:13  IP Address   136.226.19.59
# 1289  2024-11-20 10:05:10  2024-11-20 10:05:23  IP Address  170.115.248.14
#
#       Progress Duration (in seconds) Finished         RecordedDate  \
# 0          100                   505     True  2024-10-23 08:09:32
# 1          100                   499     True  2024-10-23 08:09:42
# 2          100                   538     True  2024-10-23 08:10:10
# 3          100                   368     True  2024-10-23 08:11:25
# 4          100                   639     True  2024-10-23 08:12:23
# ...        ...                   ...      ...                  ...
# 1285        37                   215    False  2024-11-20 16:32:51
# 1286        12                    51    False  2024-11-20 16:32:51
# 1287        33                   251    False  2024-11-20 16:32:51
# 1288         2                     5    False  2024-11-20 16:32:51
# 1289         2                    13    False  2024-11-20 16:32:51
#
#              ResponseId  RecipientLastName  RecipientFirstName  \
# 0     R_1S6S2YOLmv7QIc9                NaN                 NaN
# 1     R_3nSYgHp2Rm797hf                NaN                 NaN
# 2     R_6N9Q7PpNf0cQm2o                NaN                 NaN
# 3     R_6VyhD3VcG9CxJCE                NaN                 NaN
# 4     R_5iNYMYTrpdrYl2p                NaN                 NaN
# ...                 ...                ...                 ...
# 1285  R_5CijkmjipIFKfyV                NaN                 NaN
# 1286  R_5f3r2YTuSOQ8oaI                NaN                 NaN
# 1287  R_5CdrMs6s2Ld9ozB                NaN                 NaN
# 1288  R_5MSD4JDUEwz8GB4                NaN                 NaN
# 1289  R_59sSUEYZrNc2m1H                NaN                 NaN
#
#       RecipientEmail  ExternalReference LocationLatitude LocationLongitude  \
# 0                NaN                NaN          40.0149          -75.1439
# 1                NaN                NaN          40.0149          -75.1439
# 2                NaN                NaN          39.9843          -75.2266
# 3                NaN                NaN          40.0149          -75.1439
# 4                NaN                NaN          40.0172          -75.0883
# ...              ...                ...              ...               ...
# 1285             NaN                NaN              NaN               NaN
# 1286             NaN                NaN              NaN               NaN
# 1287             NaN                NaN              NaN               NaN
# 1288             NaN                NaN              NaN               NaN
# 1289             NaN                NaN              NaN               NaN
#
#      DistributionChannel UserLanguage  QID1  QID79                 Q1  \
# 0              anonymous           EN   NaN    NaN  Somewhat disagree
# 1              anonymous           EN   NaN    NaN  Strongly disagree
# 2              anonymous           EN   NaN    NaN     Somewhat agree
# 3              anonymous           EN   NaN    NaN     Strongly agree
# 4              anonymous           EN   NaN    NaN  Strongly disagree
# ...                  ...          ...   ...    ...                ...
# 1285           anonymous           EN   NaN    NaN  Strongly disagree
# 1286           anonymous           EN   NaN    NaN  Strongly disagree
# 1287           anonymous           EN   NaN    NaN  Strongly disagree
# 1288           anonymous           EN   NaN    NaN                NaN
# 1289           anonymous           EN   NaN    NaN                NaN
#
#                        Q2                 Q3                 Q4  \
# 0     Don't know/not sure     Somewhat agree  Somewhat disagree
# 1       Strongly disagree  Somewhat disagree  Strongly disagree
# 2       Somewhat disagree     Somewhat agree  Somewhat disagree
# 3          Somewhat agree     Strongly agree     Somewhat agree
# 4       Strongly disagree  Strongly disagree  Strongly disagree
# ...                   ...                ...                ...
# 1285    Strongly disagree  Somewhat disagree  Strongly disagree
# 1286       Somewhat agree  Somewhat disagree  Somewhat disagree
# 1287       Strongly agree  Strongly disagree  Strongly disagree
# 1288                  NaN                NaN                NaN
# 1289                  NaN                NaN                NaN
#
#                  Q5_1             Q5_2             Q5_3             Q5_4  \
# 0       Somewhat well    Somewhat well     Not too well    Somewhat well
# 1     Not well at all  Not well at all  Not well at all  Not well at all
# 2       Somewhat well    Somewhat well    Somewhat well    Somewhat well
# 3           Very well        Very well    Somewhat well        Very well
# 4     Not well at all  Not well at all  Not well at all  Not well at all
# ...               ...              ...              ...              ...
# 1285  Not well at all  Not well at all  Not well at all     Not too well
# 1286              NaN              NaN              NaN              NaN
# 1287     Not too well     Not too well  Not well at all  Not well at all
# 1288              NaN              NaN              NaN              NaN
# 1289              NaN              NaN              NaN              NaN
#
#                      Q6          Q7  QID43              Q8  \
# 0             Satisfied    Not sure    NaN  Somewhat agree
# 1     Very dissatisfied    Too much    NaN  Strongly agree
# 2             Satisfied    Not sure    NaN  Somewhat agree
# 3             Satisfied    Too much    NaN  Somewhat agree
# 4     Very dissatisfied    Too much    NaN  Strongly agree
# ...                 ...         ...    ...             ...
# 1285  Very dissatisfied  Too little    NaN  Somewhat agree
# 1286                NaN         NaN    NaN             NaN
# 1287       Dissatisfied    Too much    NaN  Strongly agree
# 1288                NaN         NaN    NaN             NaN
# 1289                NaN         NaN    NaN             NaN
#
#                        Q9                Q10              Q11_1  \
# 0          Somewhat agree     Somewhat agree            Neutral
# 1       Strongly disagree  Strongly disagree     Strongly agree
# 2     Don't know/Not sure  Somewhat disagree            Neutral
# 3          Somewhat agree     Somewhat agree     Somewhat agree
# 4          Strongly agree     Strongly agree     Strongly agree
# ...                   ...                ...                ...
# 1285       Somewhat agree  Somewhat disagree  Somewhat disagree
# 1286                  NaN                NaN                NaN
# 1287       Strongly agree  Strongly disagree     Strongly agree
# 1288                  NaN                NaN                NaN
# 1289                  NaN                NaN                NaN
#
#                   Q11_2              Q11_3              Q12_1  \
# 0     Somewhat disagree            Neutral  Somewhat disagree
# 1     Strongly disagree  Strongly disagree  Somewhat disagree
# 2        Somewhat agree     Somewhat agree     Somewhat agree
# 3        Somewhat agree     Somewhat agree  Strongly disagree
# 4        Strongly agree     Strongly agree     Strongly agree
# ...                 ...                ...                ...
# 1285  Strongly disagree  Strongly disagree     Strongly agree
# 1286                NaN                NaN                NaN
# 1287  Strongly disagree     Strongly agree     Strongly agree
# 1288                NaN                NaN                NaN
# 1289                NaN                NaN                NaN
#
#                   Q12_2                                              Q12-1  \
# 0        Somewhat agree                                                NaN
# 1     Strongly disagree                                                NaN
# 2        Somewhat agree                                                NaN
# 3     Somewhat disagree                                                NaN
# 4        Strongly agree                                        Race,Gender
# ...                 ...                                                ...
# 1285     Strongly agree                                      Race,Religion
# 1286                NaN                                                NaN
# 1287     Somewhat agree  Race,Sex,Gender,Family care status/your respon...
# 1288                NaN                                                NaN
# 1289                NaN                                                NaN
#
#      Q12-1_11_TEXT              Q12-2 Q12-2_11_TEXT  QID47              Q13_1  \
# 0              NaN                NaN           NaN    NaN            Neutral
# 1              NaN                NaN           NaN    NaN  Strongly disagree
# 2              NaN  Race,Age,Not sure           NaN    NaN     Somewhat agree
# 3              NaN                NaN           NaN    NaN     Somewhat agree
# 4              NaN                NaN           NaN    NaN     Strongly agree
# ...            ...                ...           ...    ...                ...
# 1285           NaN                NaN           NaN    NaN  Somewhat disagree
# 1286           NaN                NaN           NaN    NaN                NaN
# 1287           NaN                NaN           NaN    NaN                NaN
# 1288           NaN                NaN           NaN    NaN                NaN
# 1289           NaN                NaN           NaN    NaN                NaN
#
#                   Q13_2              Q13_3              Q13_4  \
# 0               Neutral            Neutral  Somewhat disagree
# 1     Strongly disagree  Strongly disagree  Strongly disagree
# 2        Somewhat agree     Somewhat agree            Neutral
# 3        Somewhat agree     Somewhat agree     Somewhat agree
# 4        Strongly agree     Strongly agree     Strongly agree
# ...                 ...                ...                ...
# 1285            Neutral  Strongly disagree  Strongly disagree
# 1286                NaN                NaN                NaN
# 1287                NaN                NaN                NaN
# 1288                NaN                NaN                NaN
# 1289                NaN                NaN                NaN
#
#                   Q13_5              Q13_6  \
# 0               Neutral            Neutral
# 1        Strongly agree  Strongly disagree
# 2               Neutral            Neutral
# 3     Somewhat disagree            Neutral
# 4     Strongly disagree  Strongly disagree
# ...                 ...                ...
# 1285     Strongly agree     Strongly agree
# 1286                NaN                NaN
# 1287                NaN                NaN
# 1288                NaN                NaN
# 1289                NaN                NaN
#
#                                                     Q14          Q15  \
# 0                                                   NaN        Never
# 1     Nothing they aren't cops and never will be the...  Hardly ever
# 2                                                   NaN  Hardly ever
# 3                                                   NaN    Sometimes
# 4                                                   NaN  Hardly ever
# ...                                                 ...          ...
# 1285                                                NaN          NaN
# 1286                                                NaN          NaN
# 1287                                                NaN          NaN
# 1288                                                NaN          NaN
# 1289                                                NaN          NaN
#
#                     Q16              Q17_1              Q17_2  \
# 0     Strongly disagree     Somewhat agree     Somewhat agree
# 1     Strongly disagree  Somewhat disagree  Somewhat disagree
# 2        Somewhat agree     Somewhat agree     Somewhat agree
# 3        Somewhat agree     Strongly agree     Strongly agree
# 4     Strongly disagree  Strongly disagree  Strongly disagree
# ...                 ...                ...                ...
# 1285                NaN                NaN                NaN
# 1286                NaN                NaN                NaN
# 1287                NaN                NaN                NaN
# 1288                NaN                NaN                NaN
# 1289                NaN                NaN                NaN
#
#                   Q18              Q19                Q20          Q21  \
# 0     Not well at all     Not too well     Somewhat agree    Sometimes
# 1     Not well at all  Not well at all     Strongly agree  Hardly ever
# 2       Somewhat well     Not too well  Somewhat disagree    Sometimes
# 3       Somewhat well    Somewhat well     Strongly agree       Always
# 4     Not well at all  Not well at all     Strongly agree       Always
# ...               ...              ...                ...          ...
# 1285              NaN              NaN                NaN          NaN
# 1286              NaN              NaN                NaN          NaN
# 1287              NaN              NaN                NaN          NaN
# 1288              NaN              NaN                NaN          NaN
# 1289              NaN              NaN                NaN          NaN
#
#                                                     Q22              Q23_1  \
# 0                                                   NaN  Strongly disagree
# 1     you have to be in the in crowd its all in who ...  Strongly disagree
# 2     Not enough opportunities or denial of opportun...  Somewhat disagree
# 3                                                   NaN     Somewhat agree
# 4                                                   NaN  Strongly disagree
# ...                                                 ...                ...
# 1285                                                NaN                NaN
# 1286                                                NaN                NaN
# 1287                                                NaN                NaN
# 1288                                                NaN                NaN
# 1289                                                NaN                NaN
#
#                   Q23_2              Q23_3                Q24  QID48  \
# 0     Strongly disagree  Somewhat disagree     Somewhat agree    NaN
# 1     Strongly disagree  Strongly disagree  Strongly disagree    NaN
# 2     Somewhat disagree  Somewhat disagree     Somewhat agree    NaN
# 3     Somewhat disagree  Somewhat disagree     Strongly agree    NaN
# 4     Strongly disagree  Strongly disagree     Strongly agree    NaN
# ...                 ...                ...                ...    ...
# 1285                NaN                NaN                NaN    NaN
# 1286                NaN                NaN                NaN    NaN
# 1287                NaN                NaN                NaN    NaN
# 1288                NaN                NaN                NaN    NaN
# 1289                NaN                NaN                NaN    NaN
#
#                  Q25                Q26                Q27  \
# 0     Somewhat agree  Strongly disagree  Strongly disagree
# 1     Strongly agree  Strongly disagree  Strongly disagree
# 2     Somewhat agree  Somewhat disagree  Strongly disagree
# 3     Somewhat agree     Strongly agree         Don't know
# 4     Strongly agree  Strongly disagree  Strongly disagree
# ...              ...                ...                ...
# 1285             NaN                NaN                NaN
# 1286             NaN                NaN                NaN
# 1287             NaN                NaN                NaN
# 1288             NaN                NaN                NaN
# 1289             NaN                NaN                NaN
#
#                                                     Q28                Q29  \
# 0                                                   NaN  Strongly disagree
# 1     its who you know doesn't matter about experience   Strongly disagree
# 2     There is too much favoritism and bias in selec...  Strongly disagree
# 3                                                   NaN         Don't know
# 4     The "rule of five" is discriminatory and is in...  Strongly disagree
# ...                                                 ...                ...
# 1285                                                NaN                NaN
# 1286                                                NaN                NaN
# 1287                                                NaN                NaN
# 1288                                                NaN                NaN
# 1289                                                NaN                NaN
#
#                                                     Q30                Q31  \
# 0                                                   NaN  Strongly disagree
# 1     same answer as the last three times you asked it   Strongly disagree
# 2     Not enough communication, a lot of hidden tran...  Somewhat disagree
# 3                                                   NaN     Somewhat agree
# 4     If you know certain high ranking officials, yo...  Strongly disagree
# ...                                                 ...                ...
# 1285                                                NaN                NaN
# 1286                                                NaN                NaN
# 1287                                                NaN                NaN
# 1288                                                NaN                NaN
# 1289                                                NaN                NaN
#
#               Q32  QID58                                            Q33  \
# 0       Sometimes    NaN  Transfers,Training and Development,Promotions
# 1     Hardly ever    NaN                                            NaN
# 2       Sometimes    NaN                 Recruiting,Retention,Transfers
# 3         Usually    NaN                                            NaN
# 4     Hardly ever    NaN                     Retention,Promotions,Other
# ...           ...    ...                                            ...
# 1285          NaN    NaN                                            NaN
# 1286          NaN    NaN                                            NaN
# 1287          NaN    NaN                                            NaN
# 1288          NaN    NaN                                            NaN
# 1289          NaN    NaN                                            NaN
#
#                   Q33_13_TEXT  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4     Ending the rule of five
# ...                       ...
# 1285                      NaN
# 1286                      NaN
# 1287                      NaN
# 1288                      NaN
# 1289                      NaN
#
#                                                     Q34  Q35     Q36  \
# 0                                                   NaN   50  Female
# 1                                                   NaN  NaN     NaN
# 2                                                   NaN   32    Male
# 3                                                   NaN   48    Male
# 4     The "rule of five" needs to be ended immediate...   47    Male
# ...                                                 ...  ...     ...
# 1285                                                NaN  NaN     NaN
# 1286                                                NaN  NaN     NaN
# 1287                                                NaN  NaN     NaN
# 1288                                                NaN  NaN     NaN
# 1289                                                NaN  NaN     NaN
#
#      Q36_3_TEXT                        Q37  Q38                     Q39  \
# 0           NaN         White or Caucasian   No                   Sworn
# 1           NaN                        NaN  NaN                     NaN
# 2           NaN  Asian or Pacific Islander  Yes                   Sworn
# 3           NaN         White or Caucasian   No  Non-sworn professional
# 4           NaN         White or Caucasian  Yes                   Sworn
# ...         ...                        ...  ...                     ...
# 1285        NaN                        NaN  NaN                     NaN
# 1286        NaN                        NaN  NaN                     NaN
# 1287        NaN                        NaN  NaN                     NaN
# 1288        NaN                        NaN  NaN                     NaN
# 1289        NaN                        NaN  NaN                     NaN
#
#                    Q39-1        Q39-2               Q39-3  \
# 0     More than 25 years          NaN  More than 25 years
# 1                    NaN          NaN                 NaN
# 2             6-10 years          NaN          6-10 years
# 3                    NaN  16-25 years         16-25 years
# 4     More than 25 years          NaN  More than 25 years
# ...                  ...          ...                 ...
# 1285                 NaN          NaN                 NaN
# 1286                 NaN          NaN                 NaN
# 1287                 NaN          NaN                 NaN
# 1288                 NaN          NaN                 NaN
# 1289                 NaN          NaN                 NaN
#
#                                                   Q12-3        Date  \
# 0                                                   NaN  2024-10-23
# 1                                                   NaN  2024-10-23
# 2                                     Race,Age,Not sure  2024-10-23
# 3                                                   NaN  2024-10-23
# 4                                           Race,Gender  2024-10-23
# ...                                                 ...         ...
# 1285                                      Race,Religion  2024-11-20
# 1286                                                NaN  2024-11-20
# 1287  Race,Sex,Gender,Family care status/your respon...  2024-11-20
# 1288                                                NaN  2024-11-20
# 1289                                                NaN  2024-11-20
#
#       Unnamed: 0          City        Country
# 0              1  Philadelphia  United States
# 1              1  Philadelphia  United States
# 2              2  Philadelphia  United States
# 3              3  Philadelphia  United States
# 4              4    Wilmington  United States
# ...          ...           ...            ...
# 1285           5  Philadelphia  United States
# 1286           6  Philadelphia  United States
# 1287          95  Philadelphia  United States
# 1288          96        Reston  United States
# 1289           6  Philadelphia  United States
#
# [1290 rows x 90 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290 entries, 0 to 1289
# Data columns (total 90 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   StartDate              1290 non-null   object
#  1   EndDate                1290 non-null   object
#  2   Status                 1290 non-null   object
#  3   IPAddress              1290 non-null   object
#  4   Progress               1290 non-null   int64
#  5   Duration (in seconds)  1290 non-null   object
#  6   Finished               1290 non-null   object
#  7   RecordedDate           1290 non-null   object
#  8   ResponseId             1290 non-null   object
#  9   RecipientLastName      0 non-null      float64
#  10  RecipientFirstName     0 non-null      float64
#  11  RecipientEmail         0 non-null      float64
#  12  ExternalReference      0 non-null      float64
#  13  LocationLatitude       843 non-null    object
#  14  LocationLongitude      843 non-null    object
#  15  DistributionChannel    1290 non-null   object
#  16  UserLanguage           1290 non-null   object
#  17  QID1                   0 non-null      float64
#  18  QID79                  0 non-null      float64
#  19  Q1                     1118 non-null   object
#  20  Q2                     1076 non-null   object
#  21  Q3                     1067 non-null   object
#  22  Q4                     1054 non-null   object
#  23  Q5_1                   1028 non-null   object
#  24  Q5_2                   1027 non-null   object
#  25  Q5_3                   1026 non-null   object
#  26  Q5_4                   1025 non-null   object
#  27  Q6                     1020 non-null   object
#  28  Q7                     1012 non-null   object
#  29  QID43                  0 non-null      float64
#  30  Q8                     1007 non-null   object
#  31  Q9                     995 non-null    object
#  32  Q10                    984 non-null    object
#  33  Q11_1                  964 non-null    object
#  34  Q11_2                  964 non-null    object
#  35  Q11_3                  961 non-null    object
#  36  Q12_1                  945 non-null    object
#  37  Q12_2                  947 non-null    object
#  38  Q12-1                  255 non-null    object
#  39  Q12-1_11_TEXT          43 non-null     object
#  40  Q12-2                  298 non-null    object
#  41  Q12-2_11_TEXT          34 non-null     object
#  42  QID47                  0 non-null      float64
#  43  Q13_1                  917 non-null    object
#  44  Q13_2                  918 non-null    object
#  45  Q13_3                  919 non-null    object
#  46  Q13_4                  913 non-null    object
#  47  Q13_5                  919 non-null    object
#  48  Q13_6                  918 non-null    object
#  49  Q14                    523 non-null    object
#  50  Q15                    901 non-null    object
#  51  Q16                    892 non-null    object
#  52  Q17_1                  884 non-null    object
#  53  Q17_2                  882 non-null    object
#  54  Q18                    879 non-null    object
#  55  Q19                    864 non-null    object
#  56  Q20                    876 non-null    object
#  57  Q21                    879 non-null    object
#  58  Q22                    655 non-null    object
#  59  Q23_1                  867 non-null    object
#  60  Q23_2                  869 non-null    object
#  61  Q23_3                  868 non-null    object
#  62  Q24                    862 non-null    object
#  63  QID48                  0 non-null      float64
#  64  Q25                    856 non-null    object
#  65  Q26                    860 non-null    object
#  66  Q27                    859 non-null    object
#  67  Q28                    691 non-null    object
#  68  Q29                    856 non-null    object
#  69  Q30                    587 non-null    object
#  70  Q31                    848 non-null    object
#  71  Q32                    842 non-null    object
#  72  QID58                  0 non-null      float64
#  73  Q33                    793 non-null    object
#  74  Q33_13_TEXT            135 non-null    object
#  75  Q34                    378 non-null    object
#  76  Q35                    733 non-null    object
#  77  Q36                    779 non-null    object
#  78  Q36_3_TEXT             6 non-null      object
#  79  Q37                    742 non-null    object
#  80  Q38                    793 non-null    object
#  81  Q39                    804 non-null    object
#  82  Q39-1                  661 non-null    object
#  83  Q39-2                  131 non-null    object
#  84  Q39-3                  792 non-null    object
#  85  Q12-3                  553 non-null    object
#  86  Date                   1290 non-null   object
#  87  Unnamed: 0             1290 non-null   int64
#  88  City                   1290 non-null   object
#  89  Country                1290 non-null   object
# dtypes: float64(10), int64(2), object(78)
# memory usage: 907.2+ KB

# %%
df['Country'].value_counts()
# Out:
# United States    1290
# Name: Country, dtype: int64

# %%
len(df['City'].unique())
# Out:
# 110

# %%
df['City'].value_counts().head(20)
# Out:
# Philadelphia         1004
# White Plains           42
# New York               23
# Reston                 16
# Lansdale                8
# Allentown               7
# St Louis                7
# Arlington               6
# Dulles                  6
# Bensalem                6
# Anaheim                 6
# Reading                 5
# Ashburn                 5
# Warrington              5
# Southampton             4
# Washington              4
# Wilmington              4
# Ballenger Creek         3
# Huntingdon Valley       3
# Warminster              3
# Name: City, dtype: int64

# %%
df.shape[0]
# Out:
# 1290

# %%
df.head()
# Out:
#              StartDate              EndDate      Status       IPAddress  \
# 0  2024-10-23 08:01:06  2024-10-23 08:09:32  IP Address  170.115.248.25
# 1  2024-10-23 08:01:22  2024-10-23 08:09:41  IP Address  170.115.248.25
# 2  2024-10-23 08:01:11  2024-10-23 08:10:10  IP Address   104.28.76.117
# 3  2024-10-23 08:05:16  2024-10-23 08:11:25  IP Address   170.115.248.7
# 4  2024-10-23 08:01:43  2024-10-23 08:12:23  IP Address    73.81.200.11
#
#    Progress Duration (in seconds) Finished         RecordedDate  \
# 0       100                   505     True  2024-10-23 08:09:32
# 1       100                   499     True  2024-10-23 08:09:42
# 2       100                   538     True  2024-10-23 08:10:10
# 3       100                   368     True  2024-10-23 08:11:25
# 4       100                   639     True  2024-10-23 08:12:23
#
#           ResponseId  RecipientLastName  RecipientFirstName  RecipientEmail  \
# 0  R_1S6S2YOLmv7QIc9                NaN                 NaN             NaN
# 1  R_3nSYgHp2Rm797hf                NaN                 NaN             NaN
# 2  R_6N9Q7PpNf0cQm2o                NaN                 NaN             NaN
# 3  R_6VyhD3VcG9CxJCE                NaN                 NaN             NaN
# 4  R_5iNYMYTrpdrYl2p                NaN                 NaN             NaN
#
#    ExternalReference LocationLatitude LocationLongitude DistributionChannel  \
# 0                NaN          40.0149          -75.1439           anonymous
# 1                NaN          40.0149          -75.1439           anonymous
# 2                NaN          39.9843          -75.2266           anonymous
# 3                NaN          40.0149          -75.1439           anonymous
# 4                NaN          40.0172          -75.0883           anonymous
#
#   UserLanguage  QID1  QID79                 Q1                   Q2  \
# 0           EN   NaN    NaN  Somewhat disagree  Don't know/not sure
# 1           EN   NaN    NaN  Strongly disagree    Strongly disagree
# 2           EN   NaN    NaN     Somewhat agree    Somewhat disagree
# 3           EN   NaN    NaN     Strongly agree       Somewhat agree
# 4           EN   NaN    NaN  Strongly disagree    Strongly disagree
#
#                   Q3                 Q4             Q5_1             Q5_2  \
# 0     Somewhat agree  Somewhat disagree    Somewhat well    Somewhat well
# 1  Somewhat disagree  Strongly disagree  Not well at all  Not well at all
# 2     Somewhat agree  Somewhat disagree    Somewhat well    Somewhat well
# 3     Strongly agree     Somewhat agree        Very well        Very well
# 4  Strongly disagree  Strongly disagree  Not well at all  Not well at all
#
#               Q5_3             Q5_4                 Q6        Q7  QID43  \
# 0     Not too well    Somewhat well          Satisfied  Not sure    NaN
# 1  Not well at all  Not well at all  Very dissatisfied  Too much    NaN
# 2    Somewhat well    Somewhat well          Satisfied  Not sure    NaN
# 3    Somewhat well        Very well          Satisfied  Too much    NaN
# 4  Not well at all  Not well at all  Very dissatisfied  Too much    NaN
#
#                Q8                   Q9                Q10           Q11_1  \
# 0  Somewhat agree       Somewhat agree     Somewhat agree         Neutral
# 1  Strongly agree    Strongly disagree  Strongly disagree  Strongly agree
# 2  Somewhat agree  Don't know/Not sure  Somewhat disagree         Neutral
# 3  Somewhat agree       Somewhat agree     Somewhat agree  Somewhat agree
# 4  Strongly agree       Strongly agree     Strongly agree  Strongly agree
#
#                Q11_2              Q11_3              Q12_1              Q12_2  \
# 0  Somewhat disagree            Neutral  Somewhat disagree     Somewhat agree
# 1  Strongly disagree  Strongly disagree  Somewhat disagree  Strongly disagree
# 2     Somewhat agree     Somewhat agree     Somewhat agree     Somewhat agree
# 3     Somewhat agree     Somewhat agree  Strongly disagree  Somewhat disagree
# 4     Strongly agree     Strongly agree     Strongly agree     Strongly agree
#
#          Q12-1 Q12-1_11_TEXT              Q12-2 Q12-2_11_TEXT  QID47  \
# 0          NaN           NaN                NaN           NaN    NaN
# 1          NaN           NaN                NaN           NaN    NaN
# 2          NaN           NaN  Race,Age,Not sure           NaN    NaN
# 3          NaN           NaN                NaN           NaN    NaN
# 4  Race,Gender           NaN                NaN           NaN    NaN
#
#                Q13_1              Q13_2              Q13_3              Q13_4  \
# 0            Neutral            Neutral            Neutral  Somewhat disagree
# 1  Strongly disagree  Strongly disagree  Strongly disagree  Strongly disagree
# 2     Somewhat agree     Somewhat agree     Somewhat agree            Neutral
# 3     Somewhat agree     Somewhat agree     Somewhat agree     Somewhat agree
# 4     Strongly agree     Strongly agree     Strongly agree     Strongly agree
#
#                Q13_5              Q13_6  \
# 0            Neutral            Neutral
# 1     Strongly agree  Strongly disagree
# 2            Neutral            Neutral
# 3  Somewhat disagree            Neutral
# 4  Strongly disagree  Strongly disagree
#
#                                                  Q14          Q15  \
# 0                                                NaN        Never
# 1  Nothing they aren't cops and never will be the...  Hardly ever
# 2                                                NaN  Hardly ever
# 3                                                NaN    Sometimes
# 4                                                NaN  Hardly ever
#
#                  Q16              Q17_1              Q17_2              Q18  \
# 0  Strongly disagree     Somewhat agree     Somewhat agree  Not well at all
# 1  Strongly disagree  Somewhat disagree  Somewhat disagree  Not well at all
# 2     Somewhat agree     Somewhat agree     Somewhat agree    Somewhat well
# 3     Somewhat agree     Strongly agree     Strongly agree    Somewhat well
# 4  Strongly disagree  Strongly disagree  Strongly disagree  Not well at all
#
#                Q19                Q20          Q21  \
# 0     Not too well     Somewhat agree    Sometimes
# 1  Not well at all     Strongly agree  Hardly ever
# 2     Not too well  Somewhat disagree    Sometimes
# 3    Somewhat well     Strongly agree       Always
# 4  Not well at all     Strongly agree       Always
#
#                                                  Q22              Q23_1  \
# 0                                                NaN  Strongly disagree
# 1  you have to be in the in crowd its all in who ...  Strongly disagree
# 2  Not enough opportunities or denial of opportun...  Somewhat disagree
# 3                                                NaN     Somewhat agree
# 4                                                NaN  Strongly disagree
#
#                Q23_2              Q23_3                Q24  QID48  \
# 0  Strongly disagree  Somewhat disagree     Somewhat agree    NaN
# 1  Strongly disagree  Strongly disagree  Strongly disagree    NaN
# 2  Somewhat disagree  Somewhat disagree     Somewhat agree    NaN
# 3  Somewhat disagree  Somewhat disagree     Strongly agree    NaN
# 4  Strongly disagree  Strongly disagree     Strongly agree    NaN
#
#               Q25                Q26                Q27  \
# 0  Somewhat agree  Strongly disagree  Strongly disagree
# 1  Strongly agree  Strongly disagree  Strongly disagree
# 2  Somewhat agree  Somewhat disagree  Strongly disagree
# 3  Somewhat agree     Strongly agree         Don't know
# 4  Strongly agree  Strongly disagree  Strongly disagree
#
#                                                  Q28                Q29  \
# 0                                                NaN  Strongly disagree
# 1  its who you know doesn't matter about experience   Strongly disagree
# 2  There is too much favoritism and bias in selec...  Strongly disagree
# 3                                                NaN         Don't know
# 4  The "rule of five" is discriminatory and is in...  Strongly disagree
#
#                                                  Q30                Q31  \
# 0                                                NaN  Strongly disagree
# 1  same answer as the last three times you asked it   Strongly disagree
# 2  Not enough communication, a lot of hidden tran...  Somewhat disagree
# 3                                                NaN     Somewhat agree
# 4  If you know certain high ranking officials, yo...  Strongly disagree
#
#            Q32  QID58                                            Q33  \
# 0    Sometimes    NaN  Transfers,Training and Development,Promotions
# 1  Hardly ever    NaN                                            NaN
# 2    Sometimes    NaN                 Recruiting,Retention,Transfers
# 3      Usually    NaN                                            NaN
# 4  Hardly ever    NaN                     Retention,Promotions,Other
#
#                Q33_13_TEXT                                                Q34  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4  Ending the rule of five  The "rule of five" needs to be ended immediate...
#
#    Q35     Q36 Q36_3_TEXT                        Q37  Q38  \
# 0   50  Female        NaN         White or Caucasian   No
# 1  NaN     NaN        NaN                        NaN  NaN
# 2   32    Male        NaN  Asian or Pacific Islander  Yes
# 3   48    Male        NaN         White or Caucasian   No
# 4   47    Male        NaN         White or Caucasian  Yes
#
#                       Q39               Q39-1        Q39-2  \
# 0                   Sworn  More than 25 years          NaN
# 1                     NaN                 NaN          NaN
# 2                   Sworn          6-10 years          NaN
# 3  Non-sworn professional                 NaN  16-25 years
# 4                   Sworn  More than 25 years          NaN
#
#                 Q39-3              Q12-3        Date  Unnamed: 0  \
# 0  More than 25 years                NaN  2024-10-23           1
# 1                 NaN                NaN  2024-10-23           1
# 2          6-10 years  Race,Age,Not sure  2024-10-23           2
# 3         16-25 years                NaN  2024-10-23           3
# 4  More than 25 years        Race,Gender  2024-10-23           4
#
#            City        Country
# 0  Philadelphia  United States
# 1  Philadelphia  United States
# 2  Philadelphia  United States
# 3  Philadelphia  United States
# 4    Wilmington  United States

# %%
city_counts = df['City'].value_counts()
major_cities = city_counts[city_counts > 5]

# Format the city count data into Markdown format
city_distribution_md = "\n".join([f"- {city}: {count} devices" for city, count in major_cities.items()])


markdown_content = f"""
Analysis on PPD surveys 11/21
===============================

The Philadelphia Police Department (PPD), in collaboration with researchers from the University of Pennsylvania, launched a Diversity, Equity, and Inclusion (DEI) survey to assess and advance its efforts toward creating a truly diverse, equitable, and inclusive workplace. This initiative is centered on fostering an environment that ensures fair treatment for all members, regardless of identity, and is a step toward aligning PPD’s practices with DEI goals. Working closely with the PPD's Interim Director of DEI, the survey was developed and launched on October 23, with a closing date set for November 20. Following the survey's release, PPD’s Director of Communications implemented a comprehensive outreach campaign to encourage maximum participation. Responses were collected both online and mail-in submissions, providing valuable insights into the department’s current climate and areas for improvement in DEI.

This report consists of three sections of analysis: **Basic Responses Distribution**, showing the distribution of respondent locations, dates, and progress; **Demographic Distribution**, covering the distributions of gender, race, sworn status, and years of service; and **Answer Distribution and Word Cloud**, displaying the response distributions and a word cloud for open-ended questions.

# Basic Responses Distribution

We convert IP address to actual cities and countries. All of the results are in United States and following is the distribution of majority cities with more than 5 devices from {df.shape[0]} survey responses including 4 mail-in responses:

{city_distribution_md}

We plot the survey received from each date and its completeness where orange is those fully completed surveys and blue are partially completed surveys:

![Survey Distribution by Date](/plots/survey_distribution.png)\n\n

We also plot the survey's progress distribution:

![Survey Progress Distribution](/plots/progress_distribution.png)\n\n
"""
print(markdown_content)
# Out:
# Analysis on PPD surveys 11/21
# ===============================
#
# The Philadelphia Police Department (PPD), in collaboration with researchers from the University of Pennsylvania, launched a Diversity, Equity, and Inclusion (DEI) survey to assess and advance its efforts toward creating a truly diverse, equitable, and inclusive workplace. This initiative is centered on fostering an environment that ensures fair treatment for all members, regardless of identity, and is a step toward aligning PPD’s practices with DEI goals. Working closely with the PPD's Interim Director of DEI, the survey was developed and launched on October 23, with a closing date set for November 20. Following the survey's release, PPD’s Director of Communications implemented a comprehensive outreach campaign to encourage maximum participation. Responses were collected both online and mail-in submissions, providing valuable insights into the department’s current climate and areas for improvement in DEI.
#
# This report consists of three sections of analysis: **Basic Responses Distribution**, showing the distribution of respondent locations, dates, and progress; **Demographic Distribution**, covering the distributions of gender, race, sworn status, and years of service; and **Answer Distribution and Word Cloud**, displaying the response distributions and a word cloud for open-ended questions.
#
# # Basic Responses Distribution
#
# We convert IP address to actual cities and countries. All of the results are in United States and following is the distribution of majority cities with more than 5 devices from 1290 survey responses including 4 mail-in responses:
#
# - Philadelphia: 1006 devices
# - White Plains: 42 devices
# - New York: 24 devices
# - Reston: 16 devices
# - Lansdale: 8 devices
# - Allentown: 7 devices
# - St Louis: 7 devices
# - Dulles: 6 devices
# - Bensalem: 6 devices
# - Anaheim: 6 devices
#
# We plot the survey received from each date and its completeness where orange is those fully completed surveys and blue are partially completed surveys:
#
# ![Survey Distribution by Date](/plots/survey_distribution.png)
#
#
#
# We also plot the survey's progress distribution:
#
# ![Survey Progress Distribution](/plots/progress_distribution.png)

# %% [markdown]
# # Answer Analysis

# %%
# questions = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5_1', 'Q5_2', 'Q5_3', 'Q5_4',
#        'Q6', 'Q7', 'Q8', 'Q9', 'Q10', 'Q11_1', 'Q11_2', 'Q11_3',
#        'Q12_1', 'Q12_2', 
#        'Q13_1', 'Q13_2', 'Q13_3', 'Q13_4', 'Q13_5', 'Q13_6',
#        'Q15', 'Q16', 'Q17_1', 'Q17_2', 'Q18', 'Q19', 'Q20', 'Q21',
#        'Q23_1', 'Q23_2', 'Q23_3', 'Q24', 'Q25', 'Q26', 'Q27',
#        'Q29', 'Q31', 'Q32', 'Q35',
#        'Q36', 'Q37', 'Q38', 'Q39', 'Q39-1', 'Q39-2']

# Other questions
# demographic: , 'Q35', 'Q36', 'Q37', 'Q38', 'Q39', 'Q39-1', 'Q39-2'
# ['Q12-1', 'Q12-2', 'Q33'] # select from multiple answers
# ['Q12-1_11_TEXT', 'Q12-2_11_TEXT','Q14', 'Q22', 'Q28', 'Q30', 'Q33_13_TEXT', 'Q34', 'Q36_3_TEXT']
# ['QID43','QID47', 'QID48', 'QID58']
# ['Q35'] # numbers
# Note: 'Q12-1', 'Q12-2' different from 'Q12_1', 'Q12_2'

# %%
# def generate_markdown(df):
#     markdown_content = ""
#     for question in questions:
#         # Calculate percentage for each answer
#         value_counts = df[question].value_counts(normalize=True) * 100
#         markdown_content += f"## {question}\n\n"

#         # Add each answer and its percentage to the markdown content
#         for answer, percentage in value_counts.items():
#             markdown_content += f"- **{answer}**: {percentage:.2f}%\n"
        
#         markdown_content += "\n"  # Add spacing between questions

#     return markdown_content

# markdown_text = generate_markdown(df)

# # with open("survey_results.md", "w") as f:
# #     f.write(markdown_text)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def word_cloud(df, question, filter=None, output_file="wordclouds/wordcloud.png"):
    # Filter the DataFrame based on the provided condition in `filter`
    if filter is not None:
        # Apply the filter condition and select the specified question column
        text = " ".join(df[filter][question].dropna().astype(str))
    else:
        # If no filter, just use the entire question column
        text = " ".join(df[question].dropna().astype(str))

    # Generate the word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Save the word cloud as an image file
    wordcloud.to_file(output_file)


# Example usage with filter
# word_cloud(df, 'Q14')
# word_cloud(df, 'Q22', df['Q21'].isin(['Always']))

# %%
order1 = ["Strongly agree", "Somewhat agree", "Somewhat disagree", "Strongly disagree", "Don't know/not sure"]
order2 = ["Very well", "Somewhat well", "Not too well", "Not well at all"]
order3 = ["Very satisfied", "Satisfied", "Dissatisfied", "Very dissatisfied"]
order4 = ["Too much", "About right", "Too little", "Not sure"]
order5 = ["Strongly agree", "Somewhat agree", "Somewhat disagree", "Strongly disagree", "Don't know/Not sure"] # Not sure
order6 = ["Strongly agree", "Somewhat agree", "Somewhat disagree", "Strongly disagree"]
order7 = ["Strongly agree", "Somewhat agree", "Neutral", "Somewhat disagree", "Strongly disagree"]
order8 = ["Always", "Usually", "Sometimes", "Hardly ever", "Never"]
order9 = ["Strongly agree", "Somewhat agree", "Somewhat disagree", "Strongly disagree", "Don't know"]
order_12 = [
    "Race", "Sex", "Gender", "Age", "Disability", "Religion", "Nationality", 
    "Sexual orientation", "Family care status/your responsibilities to your family", 
    "Military status", "Other [Please write in]"
]

order_33 = [
    "Recruiting",
    "Hiring",
    "Retention",
    "Transfers",
    "Training and Development",
    "Community engagement and relations",
    "Leadership development",
    "Promotions",
    "Written policies",
    "Workplace culture",
    "Employee support and wellbeing programs",
    "Reporting and addressing discrimination or bias",
    "Other"
]

order_39 = ['0-2 years', '3-5 years', '6-10 years', '11-15 years', '16-25 years', 'More than 25 years']

category_order = {'Q1':order1, 'Q2':order1, 'Q3':order5, 'Q4':order5, 'Q5_1':order2, 'Q5_2':order2, 'Q5_3':order2, 'Q5_4':order2,
       'Q6':order3, 'Q7':order4, 'Q8':order5, 'Q9':order5, 'Q10':order6, 'Q11_1':order7, 'Q11_2':order7, 'Q11_3':order7,
       'Q12_1':order6, 'Q12_2':order6, 'Q12-3':order_12,
       'Q13_1':order7, 'Q13_2':order7, 'Q13_3':order7, 'Q13_4':order7, 'Q13_5':order7, 'Q13_6':order7, 'Q14': 'text',
       'Q15':order8, 'Q16':order6, 'Q17_1':order6, 'Q17_2':order6, 'Q18':order2, 'Q19':order2, 'Q20':order6, 'Q21':order8, 'Q22':'text',
       'Q23_1':order9, 'Q23_2':order9, 'Q23_3':order9, 'Q24':order9, 'Q25':order6, 'Q26':order9, 'Q27':order9, 'Q28':'text',
       'Q29':order9, 'Q30':'text', 'Q31':order9, 'Q32':order8, 'Q33':order_33, 'Q34':'text'}

# %%
question_text = {
    'Q1':"Do you agree or disagree with the following statements? I am valued within the Philadelphia Police Department.", 
    'Q2':"The Philadelphia Police Department considers diverse perspectives when making decisions.", 
    'Q3':"Do you agree or disagree with the following statements? The Philadelphia Police Department communicates important information regarding departmental changes to its personnel.", 
    'Q4':"The Philadelphia Police Department communicates updates on the strategic direction of the department to its personnel.", 
    'Q5_1':"In general, how well does the Philadelphia Police Department do each of the following? \n Communicates your job responsibilities to you clearly", 
    'Q5_2':"In general, how well does the Philadelphia Police Department do each of the following? \n Trains you adequately for your job", 
    'Q5_3':"In general, how well does the Philadelphia Police Department do each of the following? \n Equips you adequately to perform your job", 
    'Q5_4':"Makes sure you are safe while doing your job",
    'Q6':"Please rate your overall satisfaction with the Philadelphia Police Department as a place to work.", 
    'Q7':"Do you feel that the Philadelphia Police Department prioritizes Diversity, Equity, and Inclusion…", 
    'Q8':"Do you agree or disagree with the following statement? I understand what Diversity, Equity, and Inclusion (DEI) is.", 
    'Q9':"Do you agree or disagree with the following statement? I feel comfortable defining DEI.", 
    'Q10':"To what extent do you agree with the following statement: “I am comfortable talking about issues related to diversity, equity, and inclusion.”", 
    'Q11_1':"To what extent do you agree or disagree with the following statements? \n The Philadelphia Police Department is dedicated to building a diverse workplace.", 
    'Q11_2':"To what extent do you agree or disagree with the following statements? \n The Philadelphia Police Department is dedicated to building an equitable workplace.", 
    'Q11_3':"To what extent do you agree or disagree with the following statements? \n The Philadelphia Police Department is dedicated to building an inclusive workplace.",
    'Q12_1':"Do you agree or disagree with the following statements: \n I have personally experienced discrimination in the Philadelphia Police Department.", 
    'Q12_2':"Do you agree or disagree with the following statements: \n I have witnessed discrimination against other people in the Philadelphia Police Department.",
    'Q13_1':"To what extent do you agree or disagree with the following statement? \n The Philadelphia Police Department values non-sworn professional staff.", 
    'Q13_2':"To what extent do you agree or disagree with the following statement? \n The Philadelphia Police Department is dedicated to the inclusiveness of non-sworn professional staff.", 
    'Q13_3':"To what extent do you agree or disagree with the following statement? \n Sworn personnel respect the work of non-sworn professional staff.", 
    'Q13_4':"To what extent do you agree or disagree with the following statement? \n Sworn personnel helps non-sworn professional staff adapt to police culture.", 
    'Q13_5':"To what extent do you agree or disagree with the following statement? \n There is a “sworn” vs. “non-sworn” culture within the Philadelphia Police Department.", 
    'Q13_6':"To what extent do you agree or disagree with the following statement? \n The relationship between non-sworn professional staff and sworn personnel at the Philadelphia Police Department needs improvement.",
    'Q15':"How often are employees in your department asked for their input on decisions that will affect them?", 
    'Q16':"When decisions are made within the Philadelphia Police Department, they are effectively communicated to Department personnel.", 
    'Q17_1':"Do you agree or disagree with the following statements: \n I am treated with respect, regardless of my identity (race, gender, age, sexual orientation, etc.).", 
    'Q17_2':"Do you agree or disagree with the following statements: \n Others are treated with respect, regardless of their identity.", 
    'Q18':"How well does the Philadelphia Police Department manage internal conflicts and disagreements among its personnel?", 
    'Q19':"How well does the Philadelphia Police Department addresses concerns and complaints raised by its personnel?", 
    'Q20':"I have access to tools to support my mental health.", 
    'Q21':"How often does the Philadelphia Police Department provide opportunities for professional development and training for its personnel?",
    'Q23_1':"Please tell us if you agree or disagree with the following statements. \n In the Philadelphia Police Department, the disciplinary process is fair.", 
    'Q23_2':"Please tell us if you agree or disagree with the following statements. \n Personnel who consistently do a poor job are held accountable.", 
    'Q23_3':"Please tell us if you agree or disagree with the following statements. \n When I do well, I am rewarded within the PPD.", 
    'Q24':"To what extent do you agree with the following statement: I feel safe reporting misconduct or unsafe conditions within the Philadelphia Police Department?", 
    'Q25':"I sometimes get conflicting instructions from my supervisors.", 
    'Q26':"Do you agree or disagree with the following statements? \n The process for assignments and promotions within the Philadelphia Police Department is effective at ensuring that people are well qualified for their positions.", 
    'Q27':"The process for transfers and assignments within the Philadelphia Police Department is fair.",
    'Q29':"The process for transfers and assignments within the Philadelphia Police Department is transparent.", 
    'Q31':"The process for promotions within the Philadelphia Police Department is fair.", 
    'Q32':"How often do you feel the Philadelphia Police Department recognizes and rewards personnel for their efforts and accomplishments on the job with new professional opportunities?",

    'Q14':"What would help improve the relationship between non-sworn and sworn personnel at the Philadelphia Police Department?",
    'Q22':"You just told us that the Philadelphia Police Department (always/usually/sometimes/hardly ever/never) provides opportunities for professional development and training for its personnel. In one sentence, can you explain why you think so?",
    'Q28':"You just told us that you (agree or disagree) that the process for transfers and assignments is fair. In one sentence, can you explain why you think so?",
    'Q30':"You just told us that you (agree or disagree) that the process for transfers and assignments is transparent. In one sentence, can you explain why you think so?",
    'Q34':"Are there any other comments or suggestions you would like to share that was not asked in this survey?",
    'Q12-3':"You said that you (strongly) agree with the statement “I have personally experienced discrimination in the Philadelphia Police Department.” Would you say that the discrimination you experienced was due to",
    'Q33':'Please select up to three areas that you believe should be prioritized by the DEI Office.\nIf you choose "Other", kindly specify any additional areas you think should be considered.\nYour insights will contribute significantly to shaping the focus and priorities of our DEI initiatives. Thank you for your valuable input.',
    'Q36':"What is your gender?",
    'Q37':"Which of the following best describes you?",
    'Q39':"Are you a sworn or non-sworn professional employee of the Philadelphia Police Department?",
    'Q39-3':"How many years have you been on the force? OR How many years have you worked for the Philadelphia Police Department?",
    }

# %%
markdown_content += "# Demographic distribution \n\n \
**Note**: Due to the small number of responses in certain categories, **Non-binary** has been combined with **Other** under gender, and **Native American or Alaskan Native** has been combined with **A race/ethnicity not listed here** in race. \n\n"

for question in ['Q36', 'Q37', 'Q39', 'Q39-3']:
    value_counts = df[question].value_counts(normalize=True) * 100
    markdown_content += f"## {question}\n **{question_text[question]}** \n\n"
    order_39 = ['0-2 years', '3-5 years', '6-10 years', '11-15 years', '16-25 years', 'More than 25 years']
    
    if question != 'Q39-3':
        for answer, percentage in value_counts.items():
            markdown_content += f"- {answer}: {percentage:.2f}%\n"
    else:
        for answer in order_39:
            if answer in value_counts:
                markdown_content += f"- {answer}: {value_counts[answer]:.2f}%\n"
    markdown_content += "\n"

# %%
# df[['Q36', 'Q37', 'Q39', 'Q39-3', 'Q21', 'Q22', 'Q27', 'Q28', 'Q29', 'Q30']].dropna(how='all').to_csv('open_ended_questions.csv')

# %%
markdown_content += "# Answer Distribution and Word Cloud\n\n\
**Note**: Questions Q14, Q22, Q28, Q30, and Q34 are open-ended and include word clouds. Questions Q12-3 and Q33 are multiple-choice. \n\n"

for question, order in category_order.items():

    markdown_content += f"## {question}\n **{question_text[question]}** \n\n"

    if question in ['Q14', 'Q34']:
        # markdown_content += "WordCloud: \n\n"
        word_cloud(df, question, output_file=f"wordclouds/{question}.png")
        markdown_content += f"![Word Cloud for {question}](/wordclouds/{question}.png)\n\n"

    elif question == 'Q22':
        markdown_content += "### WordCloud for **Always**, **Usually**, **Sometimes** \n\n"
        word_cloud(df, 'Q22', df['Q21'].isin(['Always', 'Usually', 'Sometimes']), output_file=f"wordclouds/{question}_1.png")
        markdown_content += f"![Word Cloud for {question}](/wordclouds/{question}_1.png)\n\n"

        markdown_content += "### WordCloud for **Hardly ever**, **Never** \n\n"
        word_cloud(df, 'Q22', df['Q21'].isin(['Hardly ever', 'Never']), output_file=f"wordclouds/{question}_2.png")
        markdown_content += f"![Word Cloud for {question}](/wordclouds/{question}_2.png)\n\n"

    elif question in ['Q28', 'Q30']:
        if question == 'Q28':
            prev = 'Q27'
        elif question == 'Q30':
            prev = 'Q29'

        markdown_content += "### WordCloud for **Strongly agree**, **Somewhat agree** \n"
        word_cloud(df, question, df[prev].isin(['Strongly agree', 'Somewhat agree']), output_file=f"wordclouds/{question}_1.png")
        markdown_content += f"![Word Cloud for {question}](/wordclouds/{question}_1.png)\n\n"

        markdown_content += "### WordCloud for **Somewhat disagree**, **Strongly disagree** \n"
        word_cloud(df, question, df[prev].isin(['Somewhat disagree', 'Strongly disagree']), output_file=f"wordclouds/{question}_2.png")
        markdown_content += f"![Word Cloud for {question}](/wordclouds/{question}_2.png)\n\n"
    
    elif question in ['Q12-3', 'Q33']:
        # Step 1: Expand each respondent's answer into separate rows
        df_expanded = df.assign(Choice=df[question].str.split(',')).explode('Choice')
        df_expanded['Choice'] = df_expanded['Choice'].str.strip()  # Remove any extra whitespace

        # Step 2: Calculate the percentage of respondents selecting each option
        total_responses = df[question].nunique()  # Total unique respondents
        value_counts = df_expanded['Choice'].value_counts(normalize=True) * 100
        for option in order:
            if option in value_counts:
                markdown_content += f"- {option}: {value_counts[option]:.2f}%\n"
            else:
                markdown_content += f"- {option}: 0.00%\n"
        markdown_content += "\n"

        # Step 3: Define the function to create ordered cross-tabulation tables in Markdown format
        def create_ordered_table_markdown(df_expanded, order, demographic_column):
            # Generate a cross-tabulation table
            cross_tab = pd.crosstab(df_expanded['Choice'], df_expanded[demographic_column], normalize='columns') * 100
            cross_tab = cross_tab.reindex(order)  # Ensure the rows are in the specified order
            if other_question == 'Q39-3':
                cross_tab = cross_tab[order_39]
            
            # Add Sample Size row for each demographic group
            sample_sizes = df[demographic_column].value_counts()
            cross_tab.loc['Sample Size (n)'] = sample_sizes
            
            # Convert to Markdown format
            return cross_tab.to_markdown() + "\n\n"

        for other_question in ['Q36', 'Q37', 'Q39', 'Q39-3']:
            markdown_content += create_ordered_table_markdown(df_expanded, order, other_question)

    else:
        df[question] = pd.Categorical(df[question], categories=order, ordered=True)

        value_counts = df[question].value_counts(normalize=True) * 100
        for answer in order:
            if answer in value_counts:
                markdown_content += f"- {answer}: {value_counts[answer]:.2f}%\n"
        markdown_content += "\n"  # Add spacing between questions

        def create_ordered_table_markdown(df, question, other_question):
            cross_tab_from_df = pd.crosstab(df[question], df[other_question])
            table = cross_tab_from_df.apply(lambda x: round(x / x.sum() * 100, 2), axis=0)
            table = table.reindex(order)  # Ensure the rows are in the desired order
            if other_question == 'Q39-3':
                table = table[order_39]
            table.loc['Sample Size (n)'] = cross_tab_from_df.sum().astype(int)
            
            # Convert the table to markdown format
            markdown_table = table.to_markdown() + "\n\n"  # Convert table to markdown format
            return markdown_table

        for other_question in ['Q36', 'Q37', 'Q39', 'Q39-3']:
            markdown_content += create_ordered_table_markdown(df, question, other_question)

output_path = f"PPD_analysis_112124-kg.md"
with open(output_path, 'w') as file:
    file.write(markdown_content)

# %%
output_path = f"PPD_analysis.md"
with open(output_path, 'w') as file:
    file.write(markdown_content)

# %%
markdown_content
# Out:
# '\nAnalysis on PPD surveys 11/21\n===============================\n\nThe Philadelphia Police Department (PPD), in collaboration with researchers from the University of Pennsylvania, launched a Diversity, Equity, and Inclusion (DEI) survey to assess and advance its efforts toward creating a truly diverse, equitable, and inclusive workplace. This initiative is centered on fostering an environment that ensures fair treatment for all members, regardless of identity, and is a step toward aligning PPD’s practices with DEI goals. Working closely with the PPD\'s Interim Director of DEI, the survey was developed and launched on October 23, with a closing date set for November 20. Following the survey\'s release, PPD’s Director of Communications implemented a comprehensive outreach campaign to encourage maximum participation. Responses were collected both online and mail-in submissions, providing valuable insights into the department’s current climate and areas for improvement in DEI.\n\nThis report consists of three sections of analysis: **Basic Responses Distribution**, showing the distribution of respondent locations, dates, and progress; **Demographic Distribution**, covering the distributions of gender, race, sworn status, and years of service; and **Answer Distribution and Word Cloud**, displaying the response distributions and a word cloud for open-ended questions.\n\n# Basic Responses Distribution\n\nWe convert IP address to actual cities and countries. All of the results are in United States and following is the distribution of majority cities with more than 5 devices from 1290 survey responses including 4 mail-in responses:\n\n- Philadelphia: 1006 devices\n- White Plains: 42 devices\n- New York: 24 devices\n- Reston: 16 devices\n- Lansdale: 8 devices\n- Allentown: 7 devices\n- St Louis: 7 devices\n- Dulles: 6 devices\n- Bensalem: 6 devices\n- Anaheim: 6 devices\n\nWe plot the survey received from each date and its completeness where orange is those fully completed surveys and blue are partially completed surveys:\n\n![Survey Distribution by Date](/plots/survey_distribution.png)\n\n\n\nWe also plot the survey\'s progress distribution:\n\n![Survey Progress Distribution](/plots/progress_distribution.png)\n\n\n# Demographic distribution \n\n **Note**: Due to the small number of responses in certain categories, **Non-binary** has been combined with **Other** under gender, and **Native American or Alaskan Native** has been combined with **A race/ethnicity not listed here** in race. \n\n## Q36\n **What is your gender?** \n\n- Male: 69.32%\n- Female: 27.34%\n- Other: 3.34%\n\n## Q37\n **Which of the following best describes you?** \n\n- White or Caucasian: 50.40%\n- Black or African American: 27.76%\n- Hispanic or Latino: 8.09%\n- A race/ethnicity not listed here: 7.55%\n- Multiracial or Biracial: 4.18%\n- Asian or Pacific Islander: 2.02%\n\n## Q39\n **Are you a sworn or non-sworn professional employee of the Philadelphia Police Department?** \n\n- Sworn: 83.21%\n- Non-sworn professional: 16.79%\n\n## Q39-3\n **How many years have you been on the force? OR How many years have you worked for the Philadelphia Police Department?** \n\n- 0-2 years: 5.43%\n- 3-5 years: 3.66%\n- 6-10 years: 13.01%\n- 11-15 years: 10.35%\n- 16-25 years: 32.70%\n- More than 25 years: 34.85%\n\n# Answer Distribution and Word Cloud\n\n**Note**: Questions Q14, Q22, Q28, Q30, and Q34 are open-ended and include word clouds. Questions Q12-3 and Q33 are multiple-choice. \n\n## Q1\n **Do you agree or disagree with the following statements? I am valued within the Philadelphia Police Department.** \n\n- Strongly agree: 8.50%\n- Somewhat agree: 34.26%\n- Somewhat disagree: 23.43%\n- Strongly disagree: 29.34%\n- Don\'t know/not sure: 4.47%\n\n# Answer Distribution and Word Cloud\n\n**Note**: Questions Q14, Q22, Q28, Q30, and Q34 are open-ended and include word clouds. Questions Q12-3 and Q33 are multiple-choice. \n\n## Q1\n **Do you agree or disagree with the following s ...
